# %%
import http.client

conn = http.client.HTTPSConnection("v3.football.api-sports.io")

headers = {
    'x-rapidapi-host': "v3.football.api-sports.io",
    'x-rapidapi-key': "1f5008c4f33481203631d90c7a81c5e5"
    }
conn.request("GET", "/teams/statistics?season=2024&team=33&league=39&date=2024-12-01", headers=headers)

res = conn.getresponse()
data = res.read()

print(data.decode("utf-8"))
# Out:
# {"get":"teams\/statistics","parameters":{"season":"2024","team":"33","league":"39","date":"2024-12-01"},"errors":[],"results":11,"paging":{"current":1,"total":1},"response":{"league":{"id":39,"name":"Premier League","country":"England","logo":"https:\/\/media.api-sports.io\/football\/leagues\/39.png","flag":"https:\/\/media.api-sports.io\/flags\/gb-eng.svg","season":2024},"team":{"id":33,"name":"Manchester United","logo":"https:\/\/media.api-sports.io\/football\/teams\/33.png"},"form":"WLLWDLDWLDWDW","fixtures":{"played":{"home":7,"away":6,"total":13},"wins":{"home":4,"away":1,"total":5},"draws":{"home":1,"away":3,"total":4},"loses":{"home":2,"away":2,"total":4}},"goals":{"for":{"total":{"home":11,"away":6,"total":17},"average":{"home":"1.6","away":"1.0","total":"1.3"},"minute":{"0-15":{"total":1,"percentage":"6.25%"},"16-30":{"total":1,"percentage":"6.25%"},"31-45":{"total":4,"percentage":"25.00%"},"46-60":{"total":3,"percentage":"18.75%"},"61-75":{"total":3,"percentage":"18.75%"},"
# ...

# %%
conn.request("GET", "/odds?season=2019&bet=1&bookmaker=6&fixture=157140&league=39", headers=headers)

res = conn.getresponse()
data = res.read()

# %%
import json

# %%
json.loads(data.decode("utf-8"))
# Out:
# {'get': 'odds',
#  'parameters': {'season': '2019',
#   'bet': '1',
#   'bookmaker': '6',
#   'fixture': '157140',
#   'league': '39'},
#  'errors': [],
#  'results': 0,
#  'paging': {'current': 1, 'total': 1},
#  'response': []}

# %%
conn.request("GET", "/odds/mapping", headers=headers)

res = conn.getresponse()
data = res.read()

json.loads(data.decode("utf-8"))
# Out:
# {'get': 'odds/mapping',
#  'parameters': [],
#  'errors': [],
#  'results': 100,
#  'paging': {'current': 1, 'total': 11},
#  'response': [{'league': {'id': 39, 'season': 2024},
#    'fixture': {'id': 1208193,
#     'date': '2024-12-26T15:00:00+00:00',
#     'timestamp': 1735225200},
#    'update': '2024-12-26T20:00:56+00:00'},
#   {'league': {'id': 39, 'season': 2024},
#    'fixture': {'id': 1208194,
#     'date': '2024-12-27T20:15:00+00:00',
#     'timestamp': 1735330500},
#    'update': '2024-12-27T20:00:27+00:00'},
#   {'league': {'id': 39, 'season': 2024},
#    'fixture': {'id': 1208195,
#     'date': '2024-12-27T19:30:00+00:00',
#     'timestamp': 1735327800},
#    'update': '2024-12-27T20:00:27+00:00'},
#   {'league': {'id': 39, 'season': 2024},
#    'fixture': {'id': 1208196,
#     'date': '2024-12-26T15:00:00+00:00',
#     'timestamp': 1735225200},
#    'update': '2024-12-26T20:00:56+00:00'},
#   {'league': {'id': 39, 'season': 2024},
#    'fixture': {'id': 1208197,
# ...
